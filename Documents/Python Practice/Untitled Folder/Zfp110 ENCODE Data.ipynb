# %% [markdown]
# #**Zfp110 ENCODE Datasets**
# ##25 September 2017
# ##_Drew Honson

# %%
import os
import pandas as pd
Txpt1 = pd.read_csv("Txptome.csv", index_col="Sample")
Txpt = Txpt1[["Zfp110","PRDM9","Spo11"]]

# %%
Txpt
# Out:
#                        Zfp110  PRDM9   Spo11
# Sample
# adrenal adult           1.147  0.730   0.001
# bladder adult           7.730  1.273   0.123
# cerebellum adult        3.240  0.802   0.046
# cns e11.5               4.012  0.820   0.149
# cns e14                 3.225  0.806   0.421
# cns e18                 3.742  0.493   0.310
# colon adult             1.823  1.186   0.043
# cortex adult            1.937  0.421   0.097
# duodenum adult          0.779  1.367   0.078
# frontal lobe adult      2.354  0.472   0.141
# genital fat pad adult   4.322  1.015   0.992
# heart adult             2.052  0.549   0.014
# kidney adult            2.455  1.113   0.031
# large intestine adult   2.994  1.270   0.259
# limb e14.5              4.367  0.647   0.604
# liver adult             2.124  0.978   0.003
# liver e14               2.850  0.281   0.008
# liver e14.5             2.460  0.280   0.015
# liver e18               2.900  0.762   0.043
# lung adult              2.883  0.644   0.044
# ...

# %%
import numpy as np
# %matplotlib
import matplotlib.pyplot as plt
plt.style.use("seaborn-colorblind")
# Out:
# Using matplotlib backend: MacOSX
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-45-f2d5452e1092> in <module>()
#       4 plt.style.use("seaborn-colorblind")
#       5
# ----> 6 data = np.loadtxt(Txpt, delimiter=',', skiprows = 1, usecols = range(0,3))
#       7 data = data.transpose()
#       8
#
# /Users/honsondd/anaconda/lib/python3.6/site-packages/numpy/lib/npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin)
#     976                 continue
#     977             if usecols:
# --> 978                 vals = [vals[i] for i in usecols]
#     979             if len(vals) != N:
#     980                 line_num = i + skiprows + 1
#
# /Users/honsondd/anaconda/lib/python3.6/site-packages/numpy/lib/npyio.py in <listcomp>(.0)
#     976                 continue
#     977             if usecols:
# ...
